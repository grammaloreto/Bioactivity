# %% [markdown]
# **PaDEL descriptors to transform chemical info (df) to a matrix for Random Forest algorithm**

# %%
# Unzip PaDEL descriptors file 
! unzip padel.zip

# %%
import pandas as pd

# %%
#Load data
df = pd.read_csv('psmb5_lipinski_class_pIC50.csv')

# %%
df
# Out:
#     molecule_chembl_id  ... NumHAcceptors
# 0         CHEMBL381735  ...           8.0
# 1         CHEMBL207670  ...           7.0
# 2         CHEMBL383529  ...           7.0
# 3         CHEMBL207336  ...           7.0
# 4         CHEMBL208015  ...           8.0
# ..                 ...  ...           ...
# 691      CHEMBL4519899  ...           6.0
# 692      CHEMBL4555159  ...           6.0
# 693      CHEMBL4646371  ...           6.0
# 694      CHEMBL4649310  ...           8.0
# 695      CHEMBL4635132  ...           6.0
#
# [696 rows x 8 columns]

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df_selection = df[selection]
df_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
# first five molecules
! cat molecule.smi | head -5
# Out:
# CC[C@H](C)[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CCC(=O)NC(C)(C)CC)C(=O)N[C@@H](C)C(=O)N[C@H](/C=C/S(C)(=O)=O)CC(C)C	CHEMBL381735
# CC[C@H](C)[C@H](NC(=O)OCc1ccccc1)C(=O)N1CCC[C@H]1C(=O)N[C@@H](C)C(=O)N[C@H](/C=C/S(C)(=O)=O)CC(C)C	CHEMBL207670
# CC(=O)N[C@@H](CCC(=O)OC(C)(C)C)C(=O)N[C@@H](C)C(=O)N[C@H](/C=C/S(C)(=O)=O)CC(C)C	CHEMBL383529
# CC(C)C[C@@H](/C=C/S(C)(=O)=O)NC(=O)[C@H](C)NC(=O)[C@H](CCC(=O)OC(C)(C)C)NC(=O)c1ccccc1	CHEMBL207336
# CC(C)C[C@@H](/C=C/S(C)(=O)=O)NC(=O)[C@H](C)NC(=O)[C@H](CCC(=O)OC(C)(C)C)NC(=O)OCc1ccccc1	CHEMBL208015

# %%
# Number of molecules
! cat molecule.smi | wc -l
# Out:
# 696

# %% [markdown]
# **Calculating molecular descriptors**

# %%
# Core of the PaDEL descriptor file
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
# The process
! bash padel.sh

# %% [markdown]
# **Preparing the Matrice**

# %%
# Variable X
df_X = pd.read_csv('descriptors_output.csv')

# %%
df_X
# Out:
#               Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0     CHEMBL207670           1  ...             0             0
# 1     CHEMBL381735           1  ...             0             0
# 2     CHEMBL383529           1  ...             0             0
# 3     CHEMBL207336           1  ...             0             0
# 4     CHEMBL208015           1  ...             0             0
# ..             ...         ...  ...           ...           ...
# 691  CHEMBL4519899           1  ...             0             0
# 692  CHEMBL4646371           1  ...             0             0
# 693  CHEMBL4555159           1  ...             0             0
# 694  CHEMBL4649310           1  ...             0             0
# 695  CHEMBL4635132           1  ...             0             0
#
# [696 rows x 882 columns]

# %%
#Droping the name column of compounds
df_X = df_X.drop(columns=['Name'])
df_X
# Out:
#      PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0             1           1  ...             0             0
# 1             1           1  ...             0             0
# 2             1           1  ...             0             0
# 3             1           1  ...             0             0
# 4             1           1  ...             0             0
# ..          ...         ...  ...           ...           ...
# 691           1           1  ...             0             0
# 692           1           1  ...             0             0
# 693           1           1  ...             0             0
# 694           1           1  ...             0             0
# 695           1           1  ...             0             0
#
# [696 rows x 881 columns]

# %%
# Y Variable which is pIC50
df_Y = df['pIC50']
df_Y
# Out:
# 0      8.619789
# 1      3.823909
# 2      6.585027
# 3      7.769551
# 4      8.214670
#          ...
# 691    8.522879
# 692    8.000000
# 693    5.000000
# 694    5.000000
# 695    5.000000
# Name: pIC50, Length: 696, dtype: float64

# %%
# combining X and Y in a dataset
mldataset = pd.concat([df_X,df_Y], axis=1)
mldataset
# Out:
#      PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0             1           1           1  ...             0             0  8.619789
# 1             1           1           1  ...             0             0  3.823909
# 2             1           1           1  ...             0             0  6.585027
# 3             1           1           1  ...             0             0  7.769551
# 4             1           1           1  ...             0             0  8.214670
# ..          ...         ...         ...  ...           ...           ...       ...
# 691           1           1           1  ...             0             0  8.522879
# 692           1           1           1  ...             0             0  8.000000
# 693           1           1           1  ...             0             0  5.000000
# 694           1           1           1  ...             0             0  5.000000
# ...

# %%
# Saving dataset(matrice) for ML (random forest) model
mldataset.to_csv('psmb5_pIC50_pubchem_ml.csv', index=False)
